# %% [markdown]
# <a href="https://colab.research.google.com/github/SandroBolkvadze/Facial-Expression-Recognition-Kaggle-Competition/blob/main/facial-expression-recognition-04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install dependencies

# %%
! pip install --upgrade kaggle wandb torchinfo --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.0/231.0 kB 15.2 MB/s eta 0:00:00

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import torch
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import SGD, Adam
from torchinfo import summary

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from functools import partial

# Use GPU
USE_GPU = True
device = 'cuda' if USE_GPU and torch.cuda.is_available() else 'cpu'
print('Device available:', device)
# Out:
# Device available: cuda

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Copy Access Token

# %%
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle/access_token ~/.kaggle/access_token
! chmod 600 ~/.kaggle/access_token

# %% [markdown]
# # Download Kaggle Competition Data

# %%
! kaggle competitions download -c challenges-in-representation-learning-facial-expression-recognition-challenge
# Out:
# Downloading challenges-in-representation-learning-facial-expression-recognition-challenge.zip to /content
# 100% 285M/285M [00:02<00:00, 130MB/s]

# %% [markdown]
# # Unzip Kaggle Competition Data

# %%
! unzip -o challenges-in-representation-learning-facial-expression-recognition-challenge
# Out:
# Archive:  challenges-in-representation-learning-facial-expression-recognition-challenge.zip
#   inflating: example_submission.csv
#   inflating: fer2013.tar.gz
#   inflating: icml_face_data.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# # Wandb Login

# %%
import wandb, os

with open('/content/drive/MyDrive/wandb/access_token') as file:
  token = file.read().strip()

os.environ['WANDB_API_KEY'] = token

! wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: sbolk23 (sbolk23-free-university-of-tbilisi-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Read & Transform Dataset

# %%
# Simple function for transforming 'pixels' elements
def pixels_to_image(pixels_str):
  pixels = np.array(pixels_str.split(), dtype=np.uint8)
  pixels = pixels.reshape(48, 48)
  return pixels

# %%
df = pd.read_csv('./icml_face_data.csv')

# Rename columns
df.columns = ['emotion', 'Usage', 'pixels']

# Choose Training part
df = df[df['Usage'] == 'Training']

# Drop 'Usage' column
df = df.drop(columns=['Usage'])

# Transform 'pixels' elements to numpy array in advance
df['pixels'] = df['pixels'].apply(pixels_to_image)

# %%
X = df.drop(columns=['emotion'])
y = df['emotion']

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (28709, 1)
# y shape: (28709,)

# %% [markdown]
# # Split Dataset

# %%
train_size = .7
val_size   = .15
test_size  = .15

# Split full dataset into train and val/test sets
X_train, X_val_test, y_train, y_val_test = train_test_split(
    X, y,
    test_size=(val_size+test_size)/(train_size+val_size+test_size),
    stratify=y,
)

# Split val/test dataset into 50/50 val and test sets
X_val, X_test, y_val, y_test = train_test_split(
    X_val_test, y_val_test,
    test_size=test_size/(val_size+test_size),
    stratify=y_val_test,
)

# Split full dataset into 70/15/15 train/val/test sets
print(f'X_train shape {X_train.shape} and y_train shape {y_train.shape}')
print(f'X_val shape {X_val.shape} and y_val shape {y_val.shape}')
print(f'X_test shape {X_test.shape} and y_test shape {y_test.shape}')
# Out:
# X_train shape (20096, 1) and y_train shape (20096,)
# X_val shape (4306, 1) and y_val shape (4306,)
# X_test shape (4307, 1) and y_test shape (4307,)

# %%
# Check if label distributions are same in train/val/test sets
y_train_dist = y_train.value_counts() / y_train.value_counts().sum()
y_val_dist   = y_val.value_counts()   / y_val.value_counts().sum()
y_test_dist  = y_test.value_counts()  / y_test.value_counts().sum()

# Should have roughly equal numbers across rows of 'emotions'
y_dist = pd.DataFrame({
    'y_train': y_train_dist,
    'y_val'  : y_val_dist,
    'y_test' : y_test_dist,
})

print(y_dist)
# Out:
#           y_train     y_val    y_test
# emotion
# 3        0.251294  0.251277  0.251451
# 6        0.172920  0.173014  0.172974
# 4        0.168242  0.168137  0.168331
# 2        0.142715  0.142592  0.142791
# 0        0.139182  0.139108  0.139076
# 5        0.110470  0.110543  0.110286
# 1        0.015177  0.015327  0.015092

# %% [markdown]
# # Transform Raw Pixels

# %%
# Calculate mean pixel over whole train dataset
mean_pixel = X_train['pixels'].apply(np.mean).mean() / 255.0

# Transform 2d numpy pixel array
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(mean_pixel,), std=(1.0,)),
])

# %% [markdown]
# # Custom Image Dataset

# %%
class ImageDataset(Dataset):
  def __init__(self, X, y, transform=None):
    self.X = X
    self.y = torch.tensor(y.values)
    self.transform = transform

  def __len__(self):
    return self.X.shape[0]

  def __getitem__(self, index):
    image = self.X.iloc[index, 0]
    label = self.y[index]

    if self.transform:
      image = self.transform(image)

    return image, label

# %% [markdown]
# # Datasets

# %%
train_dataset = ImageDataset(X_train, y_train, transform)
val_dataset   = ImageDataset(X_val,   y_val,   transform)
test_dataset  = ImageDataset(X_test,  y_test,  transform)

# %% [markdown]
# # Train Epoch

# %%
def train_epoch(loader, model, criterion, optimizer):
  model.train()

  total_loss, correct, total = .0, 0, 0

  for t, (x, y) in enumerate(loader):
      x, y = x.to(device), y.to(device)

      # Zero out grads
      optimizer.zero_grad()

      # Calculate scores
      scores = model(x)

      # Calculate loss
      loss = criterion(scores, y)

      # Backpropagation
      loss.backward()

      # Update model parameters
      optimizer.step()

      with torch.no_grad():
        # Update Train stats
        _, preds    = scores.max(1)
        total_loss += loss.item()
        correct    += (preds == y).sum().item()
        total      += y.shape[0]

  return total_loss / len(loader), correct / total

# %% [markdown]
# # Check Accuracy & Loss

# %%
def evaluate(loader, model, criterion=None):
  model.eval()

  total_loss, correct, total = .0, 0, 0

  with torch.no_grad():
    for t, (x, y) in enumerate(loader):
      x, y = x.to(device), y.to(device)

      scores = model(x)
      _, preds = scores.max(1)

      if criterion:
        total_loss += criterion(scores, y).item()

      correct += (preds == y).sum().item()
      total   += len(y)

  return total_loss / len(loader), correct / total

# %% [markdown]
# # Early stopping

# %%
import copy

class EarlyStopper:
  def __init__(self, patience=1, min_delta=0):
    self.patience = patience
    self.min_delta = min_delta
    self.best_loss = np.inf
    self.early_stop = False
    self.best_weights = None
    self.best_epoch = -1
    self.counter = 0

  def __call__(self, epoch, val_loss, model):
    if val_loss < self.best_loss - self.min_delta:
      self.best_epoch = epoch
      self.best_loss = val_loss
      self.counter = 0
      self.best_weights = copy.deepcopy(model.state_dict())
    else:
      self.counter += 1
      if self.counter >= self.patience:
        self.early_stop = True

    return self.early_stop

# %% [markdown]
# # Train

# %%
def train(loader_train, loader_val, model, criterion, optimizer, epochs=10, early_stopper=None, use_wandb=False):
  history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

  for e in range(1, epochs + 1):

    # Train history
    train_loss, train_acc = train_epoch(loader_train, model, criterion, optimizer)
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)

    # Validation history
    val_loss, val_acc = evaluate(loader_val, model, criterion)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # Print statistics
    print('[Epoch %d / %d]' % (e, epochs,))
    print('train_loss: %.4f; train_acc: %.4f; val_loss: %.4f; val_acc: %.4f' % (train_loss, train_acc, val_loss, val_acc,))
    print()

    if use_wandb:
      wandb.log({
        'epoch':          e,
        'train_loss':     history['train_loss'][-1],
        'train_accuracy': history['train_acc'][-1],
        'val_loss':       history['val_loss'][-1],
        'val_accuracy':   history['val_acc'][-1],
      })

    if early_stopper and early_stopper(e, val_loss, model):
      model.load_state_dict(early_stopper.best_weights)
      print('Early stopping (Epoch: %d)' % early_stopper.best_epoch)

      print(history)

      if use_wandb:
        stopped_epoch = early_stopper.best_epoch - 1
        wandb.summary['stopped_epoch']      = early_stopper.best_epoch
        wandb.summary['train_loss_at_best'] = history['train_loss'][stopped_epoch]
        wandb.summary['train_acc_at_best']  = history['train_acc'][stopped_epoch]
        wandb.summary['best_val_loss']      = history['val_loss'][stopped_epoch]
        wandb.summary['best_val_acc']       = history['val_acc'][stopped_epoch]

      break

  return history

# %% [markdown]
# # Deep CNN

# %%
class DeepCNN(nn.Module):
  def __init__(self, num_classes):
    super().__init__()

    self.conv = nn.Sequential(
        nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
        nn.MaxPool2d(2), nn.Dropout2d(0.25),

        nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
        nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
        nn.MaxPool2d(2), nn.Dropout2d(0.25),

        nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(),
        nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(),
        nn.MaxPool2d(2), nn.Dropout2d(0.25),

        nn.Conv2d(256, 512, 3, padding=1), nn.BatchNorm2d(512), nn.ReLU(),
    )

    self.mlp = nn.Sequential(
        nn.Flatten(),
        nn.Linear(512 * 6 * 6, 256), nn.ReLU(), nn.Dropout(.5),
        nn.Linear(256, num_classes),
    )

  def forward(self, x):
    x = self.conv(x)
    x = self.mlp(x)
    return x

# %% [markdown]
# # Check: Loss is reasonable for untrained model

# %%
# Create Train DataLoader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Create model, criterion, optimizer
model     = DeepCNN(7).to(device)
criterion = nn.CrossEntropyLoss()

loss, _ = evaluate(train_loader, model, criterion)
print('Loss: %.4f' % loss)
# Out:
# Loss: 1.9538

# %% [markdown]
# # Check: Model can overfit small data

# %%
# Create small data
small_data_size = 32

X_small_train, y_small_train = X_test[:small_data_size], y_test[:small_data_size]

small_dataset = ImageDataset(X_small_train, y_small_train, transform)
small_loader  = DataLoader(small_dataset, batch_size=small_data_size, shuffle=True)

# %%
# Create model, criterion, optimizer
model = DeepCNN(7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-3)

# Train model
_ = train(small_loader, small_loader, model, criterion, optimizer, epochs=15)
# Out:
# [Epoch 1 / 15]
# train_loss: 1.9115; train_acc: 0.2188; val_loss: 1.8835; val_acc: 0.2500
#
# [Epoch 2 / 15]
# train_loss: 4.9969; train_acc: 0.2188; val_loss: 1.9279; val_acc: 0.1562
#
# [Epoch 3 / 15]
# train_loss: 4.9511; train_acc: 0.1875; val_loss: 1.9938; val_acc: 0.1562
#
# [Epoch 4 / 15]
# train_loss: 6.1166; train_acc: 0.2812; val_loss: 1.9995; val_acc: 0.1562
#
# [Epoch 5 / 15]
# train_loss: 3.7782; train_acc: 0.2500; val_loss: 1.9311; val_acc: 0.1562
#
# [Epoch 6 / 15]
# train_loss: 2.9911; train_acc: 0.2500; val_loss: 1.8305; val_acc: 0.1875
#
# [Epoch 7 / 15]
# train_loss: 2.6595; train_acc: 0.2188; val_loss: 1.8009; val_acc: 0.2500
#
# [Epoch 8 / 15]
# train_loss: 2.8099; train_acc: 0.3438; val_loss: 1.7952; val_acc: 0.2500
#
# [Epoch 9 / 15]
# train_loss: 2.3490; train_acc: 0.4375; val_loss: 1.8261; val_acc: 0.2500
#
# [Epoch 10 / 15]
# train_loss: 1.7402; train_acc: 0.2500; val_loss: 1.9925; val_acc: 0.2812
#
# [Epoch 11 / 15]
# train_loss: 1.8025; train_acc: 0.3750; val_loss: 2.1477; val_acc: 0.1562
#
# [Epoch 12 / 15]
# train_loss: 1.3862; train_acc: 0.4375; val_loss: 2.3278; val_acc: 0.1562
#
# [Epoch 13 / 15]
# train_loss: 1.4854; train_acc: 0.4062; val_loss: 2.5604; val_acc: 0.1562
#
# [Epoch 14 / 15]
# train_loss: 1.7800; train_acc: 0.4062; val_loss: 2.6741; val_acc: 0.1562
#
# [Epoch 15 / 15]
# train_loss: 0.9618; train_acc: 0.6250; val_loss: 2.6687; val_acc: 0.1562

# %%
def build_name(config):
    conv_ch  = '-'.join(str(c) for c in config['conv_channels'])
    fc_sizes = '-'.join(str(s) for s in config['fc_sizes'])
    bn       = 'BN' if config.get('batch_norm', False) else 'noBN'
    drop     = f"drop_{config['dropout']}" if config.get('dropout') else 'noDrop'
    drop2d   = f"drop2d_{config['dropout2d']}" if config.get('dropout2d') else 'noDrop2d'
    opt      = config['optimizer']
    lr       = config['optimizer_kwargs']['lr']
    wd       = config['optimizer_kwargs'].get('weight_decay', 0)
    bs       = config['batch_size']

    return (
        f"DeepCNN"
        f"__conv_{conv_ch}"
        f"__fc_{fc_sizes}"
        f"__{bn}"
        f"__{drop}"
        f"__{drop2d}"
        f"__bs_{bs}"
        f"__{opt}_lr_{lr}_wd_{wd}"
    )

# %% [markdown]
# # Train DeepCNN model

# %%
config = {
    'epochs':          125,
    'batch_size':      64,
    'conv_channels':   [64, 128],
    'fc_sizes':        [256],
    'batch_norm':      True,
    'dropout':         0.5,
    'dropout2d':       0.25,
    'optimizer':       'Adam',
    'optimizer_kwargs': {'lr': 1e-4, 'weight_decay': 0},
    'early_stop':      True,
    'early_stop_kwargs': {'patience': 35, 'min_delta': 0},
}

model = DeepCNN(7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=config['optimizer_kwargs']['lr'], weight_decay=config['optimizer_kwargs']['weight_decay'])
early_stopper = EarlyStopper(patience=config['early_stop_kwargs']['patience'], min_delta=config['early_stop_kwargs']['min_delta'])

name = build_name(config)

print(name)

# Wandb init
run = wandb.init(
    project='Facial_Expression_Recognition_04',
    name=name,
    config=config
)
# Out:
# DeepCNN__conv_64-128__fc_256__BN__drop_0.5__drop2d_0.25__bs_64__Adam_lr_0.0001_wd_0
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_164747-y6jvv7xg</code>
# Syncing run <strong><a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/runs/y6jvv7xg' target="_blank">DeepCNN__conv_64-128__fc_256__BN__drop_0.5__drop2d_0.25__bs_64__Adam_lr_0.0001_wd_0</a></strong> to <a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04' target="_blank">https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04</a>
#  View run at <a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/runs/y6jvv7xg' target="_blank">https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/runs/y6jvv7xg</a>

# %%
# Create Train and Validation DataLoaders
train_loader = DataLoader(train_dataset,  batch_size=config['batch_size'], shuffle=True)
val_loader   = DataLoader(val_dataset,    batch_size=config['batch_size'], shuffle=False)

# Init wandb
wandb.watch(model, log='all')

# history = train(train_loader, val_loader, model, criterion, optimizer, epochs=config['epochs'], early_stopper=early_stopper, use_wandb=False)

# Train model
history = train(train_loader, val_loader, model, criterion, optimizer, epochs=config['epochs'], early_stopper=early_stopper, use_wandb=True)

# Save model
torch.save(model.state_dict(), f'Facial_Expression_Recognition_04_DeepCNN_{wandb.run.id}.pth')
wandb.save(f'Facial_Expression_Recognition_04_DeepCNN_{wandb.run.id}.pth')

# Finish wandb
wandb.finish()
# Out:
# [Epoch 1 / 125]
# train_loss: 1.7260; train_acc: 0.3015; val_loss: 1.5369; val_acc: 0.4027
#
# [Epoch 2 / 125]
# train_loss: 1.5313; train_acc: 0.4056; val_loss: 1.3801; val_acc: 0.4603
#
# [Epoch 3 / 125]
# train_loss: 1.4213; train_acc: 0.4557; val_loss: 1.2922; val_acc: 0.4963
#
# [Epoch 4 / 125]
# train_loss: 1.3444; train_acc: 0.4882; val_loss: 1.2449; val_acc: 0.5223
#
# [Epoch 5 / 125]
# train_loss: 1.2890; train_acc: 0.5087; val_loss: 1.2096; val_acc: 0.5265
#
# [Epoch 6 / 125]
# train_loss: 1.2452; train_acc: 0.5270; val_loss: 1.1866; val_acc: 0.5381
#
# [Epoch 7 / 125]
# train_loss: 1.2012; train_acc: 0.5472; val_loss: 1.1456; val_acc: 0.5578
#
# [Epoch 8 / 125]
# train_loss: 1.1729; train_acc: 0.5592; val_loss: 1.1224; val_acc: 0.5632
#
# [Epoch 9 / 125]
# train_loss: 1.1302; train_acc: 0.5757; val_loss: 1.1163; val_acc: 0.5669
#
# [Epoch 10 / 125]
# train_loss: 1.1012; train_acc: 0.5879; val_loss: 1.1021; val_acc: 0.5752
#
# [Epoch 11 / 125]
# train_loss: 1.0675; train_acc: 0.5976; val_loss: 1.0888; val_acc: 0.5852
#
# [Epoch 12 / 125]
# train_loss: 1.0327; train_acc: 0.6129; val_loss: 1.1202; val_acc: 0.5813
#
# [Epoch 13 / 125]
# train_loss: 1.0011; train_acc: 0.6273; val_loss: 1.1082; val_acc: 0.5845
#
# [Epoch 14 / 125]
# train_loss: 0.9785; train_acc: 0.6305; val_loss: 1.0894; val_acc: 0.5948
#
# [Epoch 15 / 125]
# train_loss: 0.9464; train_acc: 0.6427; val_loss: 1.0702; val_acc: 0.5964
#
# [Epoch 16 / 125]
# train_loss: 0.9124; train_acc: 0.6572; val_loss: 1.0710; val_acc: 0.5959
#
# [Epoch 17 / 125]
# train_loss: 0.8822; train_acc: 0.6633; val_loss: 1.0661; val_acc: 0.5982
#
# [Epoch 18 / 125]
# train_loss: 0.8431; train_acc: 0.6871; val_loss: 1.0959; val_acc: 0.5964
#
# [Epoch 19 / 125]
# train_loss: 0.8120; train_acc: 0.6977; val_loss: 1.0815; val_acc: 0.5994
#
# [Epoch 20 / 125]
# train_loss: 0.7787; train_acc: 0.7084; val_loss: 1.0707; val_acc: 0.6124
#
# [Epoch 21 / 125]
# train_loss: 0.7459; train_acc: 0.7236; val_loss: 1.1003; val_acc: 0.6170
#
# [Epoch 22 / 125]
# train_loss: 0.7078; train_acc: 0.7389; val_loss: 1.1226; val_acc: 0.6094
#
# [Epoch 23 / 125]
# train_loss: 0.6869; train_acc: 0.7432; val_loss: 1.1437; val_acc: 0.6092
#
# [Epoch 24 / 125]
# train_loss: 0.6541; train_acc: 0.7586; val_loss: 1.1403; val_acc: 0.6180
#
# [Epoch 25 / 125]
# train_loss: 0.6152; train_acc: 0.7704; val_loss: 1.1668; val_acc: 0.6194
#
# [Epoch 26 / 125]
# train_loss: 0.5941; train_acc: 0.7806; val_loss: 1.2077; val_acc: 0.6101
#
# [Epoch 27 / 125]
# train_loss: 0.5616; train_acc: 0.7940; val_loss: 1.2021; val_acc: 0.6154
#
# [Epoch 28 / 125]
# train_loss: 0.5348; train_acc: 0.8042; val_loss: 1.2349; val_acc: 0.6184
#
# [Epoch 29 / 125]
# train_loss: 0.5023; train_acc: 0.8143; val_loss: 1.2397; val_acc: 0.6064
#
# [Epoch 30 / 125]
# train_loss: 0.4936; train_acc: 0.8208; val_loss: 1.2778; val_acc: 0.6173
#
# [Epoch 31 / 125]
# train_loss: 0.4621; train_acc: 0.8323; val_loss: 1.3018; val_acc: 0.6163
#
# [Epoch 32 / 125]
# train_loss: 0.4382; train_acc: 0.8448; val_loss: 1.3167; val_acc: 0.6131
#
# [Epoch 33 / 125]
# train_loss: 0.4188; train_acc: 0.8506; val_loss: 1.3742; val_acc: 0.6168
#
# [Epoch 34 / 125]
# train_loss: 0.4075; train_acc: 0.8529; val_loss: 1.3926; val_acc: 0.6154
#
# [Epoch 35 / 125]
# train_loss: 0.3735; train_acc: 0.8676; val_loss: 1.3882; val_acc: 0.6138
#
# [Epoch 36 / 125]
# train_loss: 0.3596; train_acc: 0.8708; val_loss: 1.4439; val_acc: 0.6215
#
# [Epoch 37 / 125]
# train_loss: 0.3379; train_acc: 0.8779; val_loss: 1.4987; val_acc: 0.6119
#
# [Epoch 38 / 125]
# train_loss: 0.3271; train_acc: 0.8843; val_loss: 1.6166; val_acc: 0.6168
#
# [Epoch 39 / 125]
# train_loss: 0.3231; train_acc: 0.8851; val_loss: 1.5545; val_acc: 0.6198
#
# [Epoch 40 / 125]
# train_loss: 0.2948; train_acc: 0.8994; val_loss: 1.5319; val_acc: 0.6180
#
# [Epoch 41 / 125]
# train_loss: 0.2991; train_acc: 0.8951; val_loss: 1.5929; val_acc: 0.6198
#
# [Epoch 42 / 125]
# train_loss: 0.2940; train_acc: 0.8976; val_loss: 1.5709; val_acc: 0.6170
#
# [Epoch 43 / 125]
# train_loss: 0.2743; train_acc: 0.9040; val_loss: 1.6882; val_acc: 0.6191
#
# [Epoch 44 / 125]
# train_loss: 0.2571; train_acc: 0.9102; val_loss: 1.6801; val_acc: 0.6175
#
# [Epoch 45 / 125]
# train_loss: 0.2499; train_acc: 0.9096; val_loss: 1.6864; val_acc: 0.6108
#
# [Epoch 46 / 125]
# train_loss: 0.2474; train_acc: 0.9159; val_loss: 1.6761; val_acc: 0.6201
#
# [Epoch 47 / 125]
# train_loss: 0.2306; train_acc: 0.9220; val_loss: 1.7720; val_acc: 0.6208
#
# [Epoch 48 / 125]
# train_loss: 0.2250; train_acc: 0.9225; val_loss: 1.8498; val_acc: 0.6189
#
# [Epoch 49 / 125]
# train_loss: 0.2138; train_acc: 0.9257; val_loss: 1.8734; val_acc: 0.6180
#
# [Epoch 50 / 125]
# train_loss: 0.2187; train_acc: 0.9233; val_loss: 1.7730; val_acc: 0.6031
#
# [Epoch 51 / 125]
# train_loss: 0.2180; train_acc: 0.9261; val_loss: 1.7888; val_acc: 0.6133
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# [Epoch 52 / 125]
# train_loss: 0.1953; train_acc: 0.9334; val_loss: 1.8484; val_acc: 0.6115
#
# Early stopping (Epoch: 17)
# {'train_loss': [1.7259596020552763, 1.531255647255357, 1.4213181589819064, 1.3443785670456614, 1.289028658039251, 1.2451762484896713, 1.201236700556081, 1.1728610460925255, 1.1302485754535456, 1.1011817292043358, 1.0675184024367363, 1.0326925047263977, 1.0011274917110515, 0.9784988094666961, 0.9464462786723095, 0.9123824077427007, 0.8821938762998884, 0.8430818556600316, 0.8120416302210206, 0.7786570823496315, 0.7459220268354294, 0.7077972776001427, 0.6868899140008695, 0.654120072058052, 0.6151810357714914, 0.5940585698291754, 0.5615793893671339, 0.5347610936992487, 0.5022837435648699, 0.49360341469573366, 0.46207637230681764, 0.4381652838390344, 0.41878105339350974, 0.4075228847610723, 0.37352327888558623, 0.35956316137579597, 0.3379053448320954, 0.3271024351239584, 0.32314090454464506, 0.2947657718590111, 0.2991044175615356, 0.29399940665740115, 0.27430100499349797, 0.2570774042919563, 0.24991710135226797, 0.24735715038552405, 0.2306087730084635, 0.22503435792057377, 0.213842762717206, 0.21872496545599523, 0.21796649763253845, 0.19533238151840343], 'train_acc': [0.301453025477707, 0.4056031050955414, 0.4556628184713376, 0.48815684713375795, 0.5087082006369427, 0.5270203025477707, 0.5471735668789809, 0.5591660031847133, 0.5757364649681529, 0.5879279458598726, 0.5976313694267515, 0.6129080414012739, 0.6272890127388535, 0.6304737261146497, 0.6426652070063694, 0.6571954617834395, 0.6633160828025477, 0.6871019108280255, 0.6976512738853503, 0.7083996815286624, 0.7236265923566879, 0.7388535031847133, 0.7432324840764332, 0.7586086783439491, 0.7703523089171974, 0.7806031050955414, 0.7939888535031847, 0.8042396496815286, 0.8142914012738853, 0.8207603503184714, 0.8323049363057324, 0.8447949840764332, 0.8506170382165605, 0.852906050955414, 0.8675855891719745, 0.8707703025477707, 0.8778861464968153, 0.8843053343949044, 0.8851015127388535, 0.8994327229299363, 0.8950537420382165, 0.8976413216560509, 0.9039609872611465, 0.9101811305732485, 0.9096337579617835, 0.9158539012738853, 0.9220242834394905, 0.9225218949044586, 0.9257066082802548, 0.9233180732484076, 0.9260549363057324, 0.9333698248407644], 'val_loss': [1.5368746080819298, 1.3800691506441902, 1.2921824665630566, 1.244869384695502, 1.2096497206126942, 1.1865797963212519, 1.1455666826051825, 1.1223675976781284, 1.1163046631742926, 1.102122369057992, 1.088827099870233, 1.1202393542317783, 1.1081886300269295, 1.0894013248822267, 1.0702320871984257, 1.071032785317477, 1.0661462633048786, 1.0958856545826967, 1.081460665254032, 1.0707154948921764, 1.1002556287190493, 1.1226426170152777, 1.143726374296581, 1.1403083625961752, 1.1667730606654112, 1.2076876654344446, 1.2021396940245348, 1.2348759901874207, 1.239658336429035, 1.2777594599653692, 1.3017854287343866, 1.3166665347183453, 1.37422214448452, 1.3925597729051815, 1.3882112073547699, 1.44390309733503, 1.4986500889062881, 1.6165733591598623, 1.554546883001047, 1.5319499031585806, 1.592859809012974, 1.5709106571534102, 1.6881554757847506, 1.6801259710508234, 1.6863633473129833, 1.6761126264053232, 1.772002993261113, 1.8497776117394953, 1.8734220091034384, 1.772956115358016, 1.788789363906664, 1.8483988660223343], 'val_acc': [0.4026939154667905, 0.46028797027403623, 0.4962842545285648, 0.5222944728286112, 0.5264746864839759, 0.5380863910822109, 0.5578262888992104, 0.5631676730143985, 0.5668834184858337, 0.575243845796563, 0.5852299117510451, 0.5812819321876451, 0.584533209475151, 0.5947515095215977, 0.5963771481653507, 0.5959126799814213, 0.5982350209010683, 0.5963771481653507, 0.5993961913608917, 0.612401300510915, 0.617045982350209, 0.6093822573153739, 0.6091500232234092, 0.6179749187180679, 0.619368323269856, 0.610078959591268, 0.6154203437064562, 0.6184393869019972, 0.6063632141198327, 0.6172782164421737, 0.6163492800743149, 0.6130980027868091, 0.6168137482582443, 0.6154203437064562, 0.6137947050627032, 0.6214584300975383, 0.6119368323269856, 0.6168137482582443, 0.6198327914537854, 0.6179749187180679, 0.6198327914537854, 0.6170459823502 ...
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▂▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▅▆▆▇▇▇▇▇▇▇▇███████████████████████▇█</td></tr><tr><td>val_loss</td><td>▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆██▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>0.59824</td></tr><tr><td>best_val_loss</td><td>1.06615</td></tr><tr><td>epoch</td><td>52</td></tr><tr><td>stopped_epoch</td><td>17</td></tr><tr><td>train_acc_at_best</td><td>0.66332</td></tr><tr><td>train_accuracy</td><td>0.93337</td></tr><tr><td>train_loss</td><td>0.19533</td></tr><tr><td>train_loss_at_best</td><td>0.88219</td></tr><tr><td>val_accuracy</td><td>0.61147</td></tr><tr><td>val_loss</td><td>1.8484</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DeepCNN__conv_64-128__fc_256__BN__drop_0.5__drop2d_0.25__bs_64__Adam_lr_0.0001_wd_0</strong> at: <a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/runs/y6jvv7xg' target="_blank">https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/runs/y6jvv7xg</a><br> View project at: <a href='https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04' target="_blank">https://wandb.ai/sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260616_164747-y6jvv7xg/logs</code>

# %%
def plot_history(train_loss, train_acc, val_loss, val_acc):
    epochs = range(1, len(train_loss) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    ax1.plot(epochs, train_loss, label='Train Loss')
    ax1.plot(epochs, val_loss, label='Val Loss')
    ax1.set_title('Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()

    # Accuracy
    ax2.plot(epochs, train_acc, label='Train Acc')
    ax2.plot(epochs, val_acc, label='Val Acc')
    ax2.set_title('Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()

    plt.tight_layout()
    plt.show()

plot_history(history['train_loss'], history['train_acc'], history['val_loss'], history['val_acc'])

# %%
import wandb

api = wandb.Api()

run_id = "mmxk8tyl"

run = api.run(f"sbolk23-free-university-of-tbilisi-/Facial_Expression_Recognition_04/{run_id}")

filename = f"Facial_Expression_Recognition_04_DeepCNN_{run_id}.pth"
run.file(filename).download(replace=True)

model = DeepCNN(7).to(device)
model.load_state_dict(torch.load(filename, map_location=device))
model.eval()

# %%
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)
loss, acc = evaluate(_loader, model, nn.CrossEntropyLoss())
print(f'Loss: {loss}; acc: {100 * acc}%')
